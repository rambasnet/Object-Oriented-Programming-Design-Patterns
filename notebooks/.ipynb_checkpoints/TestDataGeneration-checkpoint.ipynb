# %% [markdown]
# # Test Data Generation
#
# - generating good test data can be challenging
# - use Hypothesis library - https://hypothesis.readthedocs.io/en/latest/index.html
# - Hypothesis is a Python library for creating unit tests by automatically generating meaningful test data
#     - helps create edge test cases in your code, you'd not have thought to look for
#     - can use it with `pytest` and `unittest` libraries
# - hypothesis provides property-based testing
# - designed to test the aspects of a data property that should always be true
# - allows for a range of inputs to be programmed and tested within a single test, rather than having to write a different test (hard-coded inputs) for every value that you want to test
# - let's you do **fuzz testing**
#     - an automated software testing method that injects invalid, malformed, or unexpected inputs into a system to reveal software defects and security vulnerabilities
# - install hypothesis library
# - more detailed examples: [https://semaphoreci.com/blog/property-based-testing-python-hypothesis-pytest](https://semaphoreci.com/blog/property-based-testing-python-hypothesis-pytest)
#
# ```bash
# pip install hypothesis
# ```
#
# - see what data you can generate and how docs: [https://hypothesis.readthedocs.io/en/latest/data.html#](https://hypothesis.readthedocs.io/en/latest/data.html#)

# %%
! pip install hypothesis
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: hypothesis in /usr/local/lib/python3.12/site-packages (6.98.10)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/site-packages (from hypothesis) (23.2.0)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /usr/local/lib/python3.12/site-packages (from hypothesis) (2.4.0)

# %%
def add(nums:list[int]) -> int:
    s: int = 0
    for n in nums:
        s += n
    return s

# %%
# typical unittesting; hardcoded input provided to functions/methods provides the expected output
assert add([1, 2, 3]) == 6, '1 2 3 did NOT add to 6'
assert add([1, 3, -1, 0, -1]) == 2, '1, 3, -1, 0, -1 did NOT add to 2'
print('all tests done...')
# Out:
# all tests done...

# %%
# see settings docs: https://hypothesis.readthedocs.io/en/latest/settings.html
from hypothesis import given, settings, Verbosity
import hypothesis.strategies as some

# %%
# By default generates 100 random lists of integers
@given(some.lists(some.integers()))
def test_add(nums):
    #print(nums) # uncomment it to see what nums are generated
    assert add(nums) == sum(nums)

# %%
test_add()

# %%
# more examples...
@given(some.integers(), some.integers())
# can set it to control the no. of examples, database, randomization, etc.
@settings(max_examples=100, verbosity=Verbosity.verbose, derandomize=True)
def test_ints_are_commutative(x, y):
    assert x + y == y + x

# %%
test_ints_are_commutative()
# Out:
# Trying example: test_ints_are_commutative(
#     x=0,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=-1153,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=-1153,
#     y=25546,
# )
# Trying example: test_ints_are_commutative(
#     x=-4626724384397176481,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=-4626724384397176481,
#     y=20354,
# )
# Trying example: test_ints_are_commutative(
#     x=10264,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=10264,
#     y=-741279336,
# )
# Trying example: test_ints_are_commutative(
#     x=17605,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=17605,
#     y=-62,
# )
# Trying example: test_ints_are_commutative(
#     x=18915,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=18915,
#     y=-3375,
# )
# Trying example: test_ints_are_commutative(
#     x=18915,
#     y=-3375,
# )
# Trying example: test_ints_are_commutative(
#     x=18915,
#     y=18915,
# )
# Trying example: test_ints_are_commutative(
#     x=-51,
#     y=127,
# )
# Trying example: test_ints_are_commutative(
#     x=-51,
#     y=127,
# )
# Trying example: test_ints_are_commutative(
#     x=-51,
#     y=127,
# )
# Trying example: test_ints_are_commutative(
#     x=127,
#     y=127,
# )
# Trying example: test_ints_are_commutative(
#     x=-28043,
#     y=-5869225121811706976,
# )
# Trying example: test_ints_are_commutative(
#     x=-237,
#     y=-5869225121811706976,
# )
# Trying example: test_ints_are_commutative(
#     x=-128,
#     y=-20851,
# )
# Trying example: test_ints_are_commutative(
#     x=0,
#     y=1366550376,
# )
# Trying example: test_ints_are_commutative(
#     x=0,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=11790,
#     y=-2779,
# )
# Trying example: test_ints_are_commutative(
#     x=11790,
#     y=-2779,
# )
# Trying example: test_ints_are_commutative(
#     x=-2779,
#     y=-2779,
# )
# Trying example: test_ints_are_commutative(
#     x=-253047653512479618,
#     y=-2779,
# )
# Trying example: test_ints_are_commutative(
#     x=-2779,
#     y=-2779,
# )
# Trying example: test_ints_are_commutative(
#     x=-2779,
#     y=-2779,
# )
# Trying example: test_ints_are_commutative(
#     x=-2779,
#     y=-2779,
# )
# Trying example: test_ints_are_commutative(
#     x=22230,
#     y=-109319570212552661558369712793357420656,
# )
# Trying example: test_ints_are_commutative(
#     x=22230,
#     y=-109319570212552661558369712793357420656,
# )
# Trying example: test_ints_are_commutative(
#     x=21054,
#     y=9479,
# )
# Trying example: test_ints_are_commutative(
#     x=21054,
#     y=9479,
# )
# Trying example: test_ints_are_commutative(
#     x=9479,
#     y=9479,
# )
# Trying example: test_ints_are_commutative(
#     x=33,
#     y=13092,
# )
# Trying example: test_ints_are_commutative(
#     x=13092,
#     y=13092,
# )
# Trying example: test_ints_are_commutative(
#     x=23204,
#     y=-26499,
# )
# Trying example: test_ints_are_commutative(
#     x=-90,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=0,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=708836661,
#     y=-17,
# )
# Trying example: test_ints_are_commutative(
#     x=-17,
#     y=-17,
# )
# Trying example: test_ints_are_commutative(
#     x=-1175018374,
#     y=-28,
# )
# Trying example: test_ints_are_commutative(
#     x=-1175018374,
#     y=70,
# )
# Trying example: test_ints_are_commutative(
#     x=70,
#     y=70,
# )
# Trying example: test_ints_are_commutative(
#     x=70,
#     y=70,
# )
# Trying example: test_ints_are_commutative(
#     x=70,
#     y=70,
# )
# Trying example: test_ints_are_commutative(
#     x=29562240726412855046445012518035321962,
#     y=-1600,
# )
# Trying example: test_ints_are_commutative(
#     x=29562240726412855046445012518035321962,
#     y=134,
# )
# Trying example: test_ints_are_commutative(
#     x=5693,
#     y=16204,
# )
# Trying example: test_ints_are_commutative(
#     x=16204,
#     y=16204,
# )
# Trying example: test_ints_are_commutative(
#     x=16204,
#     y=16204,
# )
# Trying example: test_ints_are_commutative(
#     x=-15308,
#     y=-26124,
# )
# Trying example: test_ints_are_commutative(
#     x=-15308,
#     y=-15308,
# )
# Trying example: test_ints_are_commutative(
#     x=-30804,
#     y=-35,
# )
# Trying example: test_ints_are_commutative(
#     x=-35,
#     y=-35,
# )
# Trying example: test_ints_are_commutative(
#     x=74,
#     y=100,
# )
# Trying example: test_ints_are_commutative(
#     x=74,
#     y=100,
# )
# Trying example: test_ints_are_commutative(
#     x=100,
#     y=100,
# )
# Trying example: test_ints_are_commutative(
#     x=-23330945,
#     y=-29384,
# )
# Trying example: test_ints_are_commutative(
#     x=1925742848,
#     y=-67,
# )
# Trying example: test_ints_are_commutative(
#     x=-114,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=-114,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=-41,
#     y=31466,
# )
# Trying example: test_ints_are_commutative(
#     x=1,
#     y=-890,
# )
# Trying example: test_ints_are_commutative(
#     x=3,
#     y=-890,
# )
# Trying example: test_ints_are_commutative(
#     x=3,
#     y=-890,
# )
# Trying example: test_ints_are_commutative(
#     x=3,
#     y=3,
# )
# Trying example: test_ints_are_commutative(
#     x=3,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=3,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=4348,
#     y=-1300115052,
# )
# Trying example: test_ints_are_commutative(
#     x=4348,
#     y=4348,
# )
# Trying example: test_ints_are_commutative(
#     x=7059,
#     y=-10031,
# )
# Trying example: test_ints_are_commutative(
#     x=-10031,
#     y=-10031,
# )
# Trying example: test_ints_are_commutative(
#     x=1135189261,
#     y=73,
# )
# Trying example: test_ints_are_commutative(
#     x=-1224900737,
#     y=21562,
# )
# Trying example: test_ints_are_commutative(
#     x=73,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=0,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=0,
#     y=0,
# )
# Trying example: test_ints_are_commutative(
#     x=-896,
#     y=-96,
# )
# Trying example: test_ints_are_commutative(
#     x=-896,
#     y=-96,
# )
# Trying example: test_ints_are_commutative(
#     x=-32471,
#     y=24996,
# )
# Trying example: test_ints_are_commutative(
#     x=-638,
#     y=24996,
# )
# Trying example: test_ints_are_commutative(
#     x=-638,
#     y=-638,
# )
# Trying example: test_ints_are_commutative(
#     x=375731347,
#     y=-30809,
# )
# Trying example: test_ints_are_commutative(
#     x=375731347,
#     y=2,
# )
# Trying example: test_ints_are_commutative(
#     x=2,
#     y=2,
# )
# Trying example: test_ints_are_commutative(
#     x=50,
#     y=81,
# )
# Trying example: test_ints_are_commutative(
#     x=50,
#     y=81,
# )
# Trying example: test_ints_are_commutative(
#     x=50,
#     y=50,
# )
# Trying example: test_ints_are_commutative(
#     x=838893874,
#     y=-18,
# )
# Trying example: test_ints_are_commutative(
#     x=838893874,
#     y=50,
# )
# Trying example: test_ints_are_commutative(
#     x=838893874,
#     y=-3306536,
# )
# Trying example: test_ints_are_commutative(
#     x=-3306536,
#     y=-3306536,
# )
# Trying example: test_ints_are_commutative(
#     x=31375,
#     y=10,
# )
# Trying example: test_ints_are_commutative(
#     x=-122,
#     y=10,
# )
# Trying example: test_ints_are_commutative(
#     x=-122,
#     y=-122,
# )
# Trying example: test_ints_are_commutative(
#     x=-26,
#     y=-26332,
# )
# Trying example: test_ints_are_commutative(
#     x=-79518336208925090,
#     y=-5909,
# )
# Trying example: test_ints_are_commutative(
#     x=-5909,
#     y=-5909,
# )
# Trying example: test_ints_are_commutative(
#     x=-5909,
#     y=898,
# )

# %%
# explicitly give name to data
@given(x=some.integers(), y=some.integers())
def test_ints_cancel(x, y):
    assert (x + y) - y == x

# %%
test_ints_cancel()

# %%
# generate lists of arbitrary length (usually between 0 and
# 100 elements) whose elements are integers.
@given(some.lists(some.integers()))
def test_reversing_twice_gives_same_list(xs):
    ys = list(xs)
    ys.reverse()
    ys.reverse()
    assert ys == xs

# %%
test_reversing_twice_gives_same_list()

# %%
@given(some.tuples(some.booleans(), some.text()))
def test_look_tuples_work_too(t):
    # A tuple is generated as the one you provided, 
    # with the corresponding types in those positions.
    assert len(t) == 2
    assert isinstance(t[0], bool)
    assert isinstance(t[1], str)

# %%
# generate even numbers between 10 and 20
# use min_value and max_value or map method
@given(some.integers(min_value=5, max_value=10).map(lambda x: x*2))
def test_somefunc(num):
    print(num)
    #assert test some functions using nums!

# %%
test_somefunc()
# Out:
# 10
# 20
# 18
# 12
# 16
# 14

# %%
# can compose types such as list, tuple, etc...
# list with at most 100 integers with min value of 1
@given(some.lists(some.integers(min_value=1), max_size=100))
def test_func1(nums):
    print(nums)

# %%
test_func1()
# Out:
# []
# [1]
# [13078]
# [13078, 21]
# [14118]
# [14554]
# [15344]
# [20581]
# [7122]
# [8779342449422759215]
# [111]
# [13506, 538037116, 90, 14615, 28236, 18]
# [13506, 538037116, 90, 14615, 28236, 18]
# [13506, 538037116, 90, 14615, 28236, 18]
# [13506, 538037116, 90, 14615, 90, 18]
# [13506, 538037116, 90, 14615, 90, 7809, 61, 31290, 4, 11706]
# [13506, 14615, 90, 7809, 61, 31290, 4, 11706]
# [13506, 14615, 90, 7809, 61, 31290, 4, 11706]
# [93]
# [93, 15543, 110, 23747, 29577, 32740]
# [93, 15543, 110, 23747, 29577, 32740, 25872, 5298, 122, 1455, 20742, 7331, 27351, 15134, 1469, 70, 19426, 25, 30242, 417149929, 3651692608442995658, 3650, 4470, 19, 13, 49]
# [93, 15543, 110, 23747, 29577, 32740, 25872, 5298, 122, 1455, 20742, 7331, 27351, 15134, 1469, 70, 19426, 25, 30242, 417149929, 3651692608442995658, 3650, 4470, 19, 13, 49]
# [93, 15543, 110, 23747, 29577, 32740, 25872, 5298, 122, 1455, 20742, 7331, 27351, 15134, 1469, 70, 19426, 25, 30242, 417149929, 3651692608442995658, 3650, 4470, 19, 13, 49]
# [93, 15543, 110, 23747, 29577, 32740, 25872, 5298, 122, 1455, 20742, 7331, 27351, 15134, 1469, 641, 24834]
# [93, 15543, 110, 23747, 29577, 32740, 25872, 5298, 122, 20742, 7331, 27351, 15134, 1469, 641, 24834]
# [31318, 26086, 17674, 11833, 32599, 7509, 16884, 18879, 19915, 1704216064, 1840, 41, 31820]
# [31318, 26086, 17674, 11833, 32599, 7509, 16884, 18879, 19915, 1704216064, 1840, 41, 31820]
# [31318, 26086, 17674, 11833, 11833, 32599, 7509, 16884, 18879, 19915, 1704216064, 1840, 41, 31820]
# [31318, 26086, 1704216064, 11833, 11833, 32599, 7509, 16884, 18879, 19915, 1704216064, 1840, 41, 31820]
# [31318, 26086, 1704216064, 11833, 11833, 32599, 7509, 32599, 18879, 19915, 1704216064, 1840, 41, 31820]
# [31318, 26086, 1704216064, 18879, 11833, 32599, 7509, 32599, 18879, 19915, 1704216064, 1840, 41, 31820]
# [31318, 26086, 1704216064, 1704216064, 11833, 32599, 7509, 32599, 18879, 19915, 1704216064, 1840, 41, 31820]
# [24525, 70, 5440211488758099174]
# [24525, 70, 5440211488758099174]
# [24525, 24525, 5440211488758099174]
# [24525, 24525, 5440211488758099174]
# [19025]
# [19025, 5813, 1482738609, 60, 27876, 3879, 32, 11409, 27]
# [19025, 5813, 747635204]
# [13086, 12, 64, 18085, 12474, 11632, 95255541590956055755537252558120155018, 7263]
# [13086, 12, 64, 18085, 12474, 11632, 95255541590956055755537252558120155018, 7263]
# [130, 292]
# [130]
# [130, 130, 25, 107, 7713047656579319255, 6988]
# [130, 130, 25, 107, 7713047656579319255, 6988]
# [130, 130, 25, 107, 7713047656579319255, 6988]
# [126]
# [126, 6340, 7995, 21090, 62]
# [126, 6521493841760125185, 386, 96, 5136, 50]
# [6521493841760125185, 386, 96, 5136, 50]
# [6521493841760125185, 386, 1, 385, 1]
# [6521493841760125185, 1, 1, 385, 1]
# [6521493841760125185, 1, 1, 385, 1]
# [21802, 9167, 11183]
# [21802, 9167, 11183, 63, 1162805630, 19, 27645, 4459, 83]
# [21802, 9167, 11183]
# [21802, 11183, 11183]
# [21802, 2, 11183]
# [21802, 2, 11183, 20803067515688983140114335988666973782, 23, 25254, 31508, 24532, 42]
# [21802, 2, 11183, 5212698283577682063191367177405313, 641]
# [29590, 31253, 2480, 12366]
# [29590, 31253, 2480, 12366]
# [31253]
# [31253]
# [58, 24285, 94, 2296, 17801, 1970582753, 47819521922474111386744542389483444109, 11287]
# [58, 24285, 94, 2296, 17801, 1970582753, 17801, 11287]
# [58, 24285, 94, 2296, 17801, 3, 17801, 11287]
# [58, 24285, 94, 2296, 17801, 3, 11287]
# [58, 24285, 94, 2296, 17801, 3, 11287, 94]
# [58, 24285, 94, 2296, 17801, 3, 11287, 94, 25655, 18827]
# [58, 24285, 94, 2296, 17801, 3, 3176729346715123714, 25655, 18827]
# [20323, 70702518612689059518587587911170424113, 661809767, 121, 19492, 3613350605964448301, 21792, 30300, 66, 28481]
# [20323, 70702518612689059518587587911170424113, 661809767, 121, 19492, 3613350605964448301, 771, 257, 1, 28481]
# [20323, 70702518612689059518587587911170424113, 28481, 121, 19492, 3613350605964448301, 771, 257, 1, 28481]
# [20323, 70702518612689059518587587911170424113, 28481, 121, 19492, 3613350605964448301, 771, 257, 1, 28481]
# [20323, 70702518612689059518587587911170424113, 28481, 121, 19492, 3613350605964448301, 771, 257, 1, 28481]
# [20323, 70702518612689059518587587911170424113, 28481, 121, 19492, 3613350605964448301, 771, 257, 1, 771]
# [20323, 70702518612689059518587587911170424113, 28481, 121, 19492, 3613350605964448301, 771, 257, 1, 771]
# [16464, 14848, 25363, 19660, 1048318920]
# [16464, 14848, 25, 25363, 19660, 1048318920]
# [16464, 14848, 25, 25363, 19660, 14848]
# [16464, 14848, 65, 1]
# [16464, 14848, 65, 1]
# [1, 14848, 65, 1]
# [1, 14848, 14848, 1]
# [65, 18969, 1727869685, 128, 32288, 1, 19478, 924729876, 7479610059731761322, 124, 278, 28924, 2137, 1821327431, 27242, 204048818]
# [65, 18969, 1727869685, 128, 32288, 1, 19478, 924729876, 7479610059731761322, 124, 278, 28924, 27242, 1821327431, 27242, 204048818]
# [65, 18969, 1727869685, 128, 32288, 1, 19478, 7479610059731761322, 7479610059731761322, 124, 278, 28924, 27242, 1821327431, 27242, 204048818]
# [65, 18969, 1727869685, 128, 32288, 1, 19478, 7479610059731761322, 7479610059731761322, 124, 278, 28924, 27242, 1821327431, 27242, 204048818]
# [65, 18969, 1727869685, 127, 72201638656087299, 3, 1]
# [65, 18969, 1727869685, 127, 72201638656087299, 3, 1]
# [65, 1727869685, 127, 72201638656087299, 3, 1]
# [867, 126, 33, 18016, 14003, 4041001980368144204, 49, 7017783004762060019, 105, 28, 320250882, 30727, 14600, 13980, 119, 76]
# [867, 126, 33, 18016, 14003, 4041001980368144204, 49, 7017783004762060019, 105, 28, 320250882, 30727, 14600, 13980, 119, 76]
# [867, 126, 18016, 14003, 4041001980368144204, 49, 7017783004762060019, 105, 28, 320250882, 30727, 14600, 13980, 119, 76]
# [867, 126, 18016, 14003, 4041001980368144204, 49, 7017783004762060019, 105, 28, 320250882, 30727, 14600, 13980, 119, 76]
# [867, 126, 18016, 14003, 4041001980368144204, 49, 7017783004762060019, 105, 4041001980368144204, 320250882, 30727, 14600, 13980, 119, 76]
# [867, 126, 18016, 14003, 4041001980368144204, 49, 7017783004762060019, 105, 4041001980368144204, 320250882, 30727, 14600, 13980, 119, 76]
# [867, 126, 18016, 14003, 4041001980368144204, 49, 7017783004762060019, 105, 4041001980368144204, 320250882, 30727, 76, 13980, 119, 76]
# [10, 1943922807, 27268, 104, 125, 106, 616936840]

# %% [markdown]
# ### Software Requirement
#
# 1. Define a function that takes an integer value between 1 and 10 as an argument
# 2. Function finds and returns the square root of the integer value provided

# %%
def int_sqrt(n: int) -> float:
    # Is this the correct implementation?
    return n**0.5

# %%
def test_int_sqrt():
    assert int_sqrt(9) == 3, 'sqrt(9) != 3'
    assert int_sqrt(4) == 2, 'sqrt(4) != 2'
    #assert int_sqrt(100) == 10, 'sqrt(100) != 10'
    # any problem here...?
    print('all tests PASS...')

# %%
test_int_sqrt()
# Out:
# all tests PASS...

# %%
# Property-based testing using hypothesis
from dataclasses import dataclass
import hypothesis.strategies as st

@dataclass
class TestData:
    int_value: st.SearchStrategy[int]

# Generating correct input data range
test_data = TestData(int_value=st.integers(min_value=1, max_value=10))

# %%
@given(st.data())
def test_int_sqrt(data: st.DataObject):
    import math

    an_int = data.draw(test_data.int_value)
    root = int_sqrt(an_int)
    # TODO: uncomment to see the test data
    #print(an_int, root) 

    assert isinstance(an_int, int)
    assert root == math.sqrt(an_int)
    print('all answer correct')

# %%
test_int_sqrt()
# Out:
# all answer correct
# all answer correct
# all answer correct
# all answer correct
# all answer correct
# all answer correct
# all answer correct
# all answer correct
# all answer correct
# all answer correct

# %%
# What if you pass a string, -negative, 0, float, larger than 10 values...?

# Let's test for -ve values
@given(some.integers(min_value=-100000, max_value=-1))
def test_int_sqrt_negative(n: int):
    # This should throw AssertionError, but does it...?
    try:
        #print(n)
        root = int_sqrt(n)
    except AssertionError:
        # This must be printed... to pass the test
        print('assertion error thrown... PASS')
    else:
        print('FAIL')

# %%
test_int_sqrt_negative()
# Out:
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL

# %%
# let's test for larger than 10 values
@given(some.integers(min_value=11, max_value=100))
def test_int_sqrt_larger_positives(n: int):
    # This should throw AssertionError, but does it...?
    try:
        #print(n)
        root = int_sqrt(n)
    except AssertionError:
        # This must be printed... to pass the test
        print('assertion error thrown... PASS')
    else:
        print('FAIL')

# %%
test_int_sqrt_larger_positives()
# Out:
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL

# %%
# let's test with float values
@given(some.floats())
def test_int_sqrt_floats(n: float):
    # This should raise AssertionError, but does it...?
    try:
        #print(n)
        root = int_sqrt(n)
    except AssertionError:
        # This must be printed... to pass the test
        print('assertion error thrown... PASS')
    else:
        print('FAIL')

# %%
test_int_sqrt_floats()
# Out:
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL

# %%
# Let's test with some strings
@given(some.text())
def test_int_sqrt_strings(n: str):
    # This should throw AssertionError, but does it...?
    try:
        #print(n)
        root = int_sqrt(n)
    except AssertionError:
        # This must be printed... to pass the test
        print('assertion error thrown...PASS')
    else:
        print('FAIL')

# %%
test_int_sqrt_strings()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 test_int_sqrt_strings()
#
# Cell In[29], line 3, in test_int_sqrt_strings()
#       1 # Let's test with some strings
#       2 @given(some.text())
# ----> 3 def test_int_sqrt_strings(n: str):
#       4     # This should throw AssertionError, but does it...?
#       5     try:
#       6         #print(n)
#       7         root = int_sqrt(n)
#
#     [... skipping hidden 1 frame]
#
# Cell In[29], line 7, in test_int_sqrt_strings(n)
#       2 @given(some.text())
#       3 def test_int_sqrt_strings(n: str):
#       4     # This should throw AssertionError, but does it...?
#       5     try:
#       6         #print(n)
# ----> 7         root = int_sqrt(n)
#       8     except AssertionError:
#       9         # This must be printed... to pass the test
#      10         print('assertion error thrown...PASS')
#
# Cell In[17], line 5, in int_sqrt(n)
#       3 def int_sqrt(n: int) -> float:
#       4     # Is this the correct implementation?
# ----> 5     return n**0.5
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'float'
# Falsifying example: test_int_sqrt_strings(
#     n='',  # or any other generated value
# )
# Explanation:
#     These lines were always and only run by failing examples:
#         /usr/local/lib/python3.12/functools.py:76
#         /usr/local/lib/python3.12/typing.py:2140
#         /usr/local/lib/python3.12/weakref.py:210
#         /usr/local/lib/python3.12/weakref.py:499

# %% [markdown]
# ## Fix int_sqrt( ) so all property-based test PASS
#
# - since all the tests use an AssertionError exception, use assert to fix various properties of the input data
#     - assert num >= 1 and num <= 10
#     - ...
# - you could decide to throw your custom error for invalid data and assert those errors accordingly
# - re-run all the property-based tests so every test PASSes

# %% [markdown]
# ## Property-based testing demo
#
# - see `src/unittesting/inventory` folder
#     - a simple order processing and stock control system
#     - burrowed from book "The Pragmatic Programmer" by David Thomas and Andrew Hunt
# - two classes:
#     - `Warehouse` and `Order` in two separate modules
# - run several test modules provided in the order:
# - if the Warehouse doesn't have enough inventory, you shouldn't be able to create an Order!
#     - Hypothesis will find this bug and report it!
#
# ```bash
# pytest test_order.py
# pytest test_order1.py # <-- this property-based testing using hypothesis will find error
# pytest test_warehouse.py
# pytest test_order_fixed.py
# ```
#
# - performs several property-based tests
# - automatically generates test data using `hypothesis`
# - finds the data that causes tests to fail
#     - use the data to create the separate explicit `unittest` - which becomes your regression test
#     - since the data is generated randomly, you may not guarantee the same data will be generated
# - property-based tests often surprise you!
#
# ### Regression test
# - focus on the subset of unit tests targeting a subset of new code/feature
# - a type of software testing technique that re-runs functional and non-functional tests to ensure that a software application works as intended after any code changes, updates, revisions, improvements, or optimizations
# - change int_sqrt( ) function to accept values from 0 to 100
# - see if the existing test passes
#     - do you need new property-based tests?
